# %%
import numpy as np
import pandas as pd
import openpyxl as xl

# %%
df = pd.read_excel("products.xlsx")

# %%
df
# Out:
#                 product_id   price  merchant_id      brand  \
# 0     AVphzgbJLJeJML43fA0o  104.99         1001      Sanus
# 1     AVpgMuGwLJeJML43KY_c   69.00         1002    Boytone
# 2     AVpe9FXeLJeJML43zHrq   23.99         1001      DENAQ
# 3     AVpfVJXu1cnluZ0-iwTT  290.99         1001  DreamWave
# 4     AVphUeKeilAPnD_x3-Be  244.01         1004     Yamaha
# ...                    ...     ...          ...        ...
# 1240  AVphFybdLJeJML43Wnza   64.95         1110        JBL
# 1241  AVpe_qIa1cnluZ0-bjrN  871.06         1002         HP
# 1242  AVphibxI1cnluZ0-DpxG   74.95         1238   Magellan
# 1243  AVpgrtW3ilAPnD_xv67M  294.35         1239   Pyle Pro
# 1244  AVpgibRDLJeJML43PTZX  129.99         1001       naxa
#
#                                                    name
# 0     Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# 1     Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 2              DENAQ - AC Adapter for TOSHIBA SATELLITE
# ...

# %% [markdown]
# # common parameters for read_excel()
#
# - `filepath`: Path of the file to be read.
# - `sheet_name`: Strings are used for sheet names. Integers are used in zero-indexed sheet positions. Lists of strings/integers are used to request multiple sheets. Specify None to get all sheets.
# - `header`: Index of the row containing the names of the columns (None if none).
# - `index_col`: Index of the column or sequence of indexes that should be used as index of rows of the data.
# - `names`: Sequence containing the names of the columns (used together with header = None).
# - `skiprows`: Number of rows or sequence of row indexes to ignore in the load.
# - `na_values`: Sequence of values that, if found in the file, should be treated as NaN.
# - `dtype`: Dictionary in which the keys will be column names and the values will be types of NumPy to which their content must be converted.
# - `parse_dates`: Flag that indicates if Python should try to parse data with a format similar to dates as dates. You can enter a list of column names that must be joined for the parsing as a date.
# - `date_parser`: Function to use to try to parse dates.
# - `nrows`: Number of rows to read from the beginning of the file.
# - `skip_footer`: Number of rows to ignore at the end of the file.
# - `thousands`: Character to use to detect the thousands separator.

# %%
#ADDING index_col and establishing as index
df = pd.read_excel("products.xlsx", index_col=[0])
df
# Out:
#                        price  merchant_id      brand  \
# product_id
# AVphzgbJLJeJML43fA0o  104.99         1001      Sanus
# AVpgMuGwLJeJML43KY_c   69.00         1002    Boytone
# AVpe9FXeLJeJML43zHrq   23.99         1001      DENAQ
# AVpfVJXu1cnluZ0-iwTT  290.99         1001  DreamWave
# AVphUeKeilAPnD_x3-Be  244.01         1004     Yamaha
# ...                      ...          ...        ...
# AVphFybdLJeJML43Wnza   64.95         1110        JBL
# AVpe_qIa1cnluZ0-bjrN  871.06         1002         HP
# AVphibxI1cnluZ0-DpxG   74.95         1238   Magellan
# AVpgrtW3ilAPnD_xv67M  294.35         1239   Pyle Pro
# AVpgibRDLJeJML43PTZX  129.99         1001       naxa
#
#                                                                    name
# product_id
# AVphzgbJLJeJML43fA0o  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# AVpe9FXeLJeJML43zHrq           DENAQ - AC Adapter for TOSHIBA SATELLITE
# ...

# %%
# selecting specific sheet from excel
df2 = pd.read_excel("products.xlsx", sheet_name="Products", index_col=[0])
df2
# Out:
#                        price  merchant_id      brand  \
# product_id
# AVphzgbJLJeJML43fA0o  104.99         1001      Sanus
# AVpgMuGwLJeJML43KY_c   69.00         1002    Boytone
# AVpe9FXeLJeJML43zHrq   23.99         1001      DENAQ
# AVpfVJXu1cnluZ0-iwTT  290.99         1001  DreamWave
# AVphUeKeilAPnD_x3-Be  244.01         1004     Yamaha
# ...                      ...          ...        ...
# AVphFybdLJeJML43Wnza   64.95         1110        JBL
# AVpe_qIa1cnluZ0-bjrN  871.06         1002         HP
# AVphibxI1cnluZ0-DpxG   74.95         1238   Magellan
# AVpgrtW3ilAPnD_xv67M  294.35         1239   Pyle Pro
# AVpgibRDLJeJML43PTZX  129.99         1001       naxa
#
#                                                                    name
# product_id
# AVphzgbJLJeJML43fA0o  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# AVpe9FXeLJeJML43zHrq           DENAQ - AC Adapter for TOSHIBA SATELLITE
# ...

# %%
#load another sheet named merchants
df3 = pd.read_excel("products.xlsx", sheet_name="Merchants", index_col="merchant_id")
df3
# Out:
#                      merchant
# merchant_id
# 1001              Bestbuy.com
# 1002              Walmart.com
# 1003              Bestbuy.com
# 1004                 Growkart
# 1005         bhphotovideo.com
# ...                       ...
# 1236              PRIMESELLER
# 1237                  Spy Tec
# 1238              Action Gear
# 1239            Overstock.com
# 1240                  unknown
#
# [240 rows x 1 columns]

# %%
# The ExcelFile class object

# %%
excel_file =pd.ExcelFile("products.xlsx") # this is a file object that can be used to read multiple sheets from the same excel file

# %%
excel_file.sheet_names # list of sheet names in the excel file
# Out:
# ['Products', 'Descriptions', 'Merchants']

# %%
# parse() method on ExcelFile object to load specific sheet into DataFrame
df4 = pd.read_excel(excel_file, sheet_name="Products", index_col=[0])
df4
# Out:
#                        price  merchant_id      brand  \
# product_id
# AVphzgbJLJeJML43fA0o  104.99         1001      Sanus
# AVpgMuGwLJeJML43KY_c   69.00         1002    Boytone
# AVpe9FXeLJeJML43zHrq   23.99         1001      DENAQ
# AVpfVJXu1cnluZ0-iwTT  290.99         1001  DreamWave
# AVphUeKeilAPnD_x3-Be  244.01         1004     Yamaha
# ...                      ...          ...        ...
# AVphFybdLJeJML43Wnza   64.95         1110        JBL
# AVpe_qIa1cnluZ0-bjrN  871.06         1002         HP
# AVphibxI1cnluZ0-DpxG   74.95         1238   Magellan
# AVpgrtW3ilAPnD_xv67M  294.35         1239   Pyle Pro
# AVpgibRDLJeJML43PTZX  129.99         1001       naxa
#
#                                                                    name
# product_id
# AVphzgbJLJeJML43fA0o  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# AVpe9FXeLJeJML43zHrq           DENAQ - AC Adapter for TOSHIBA SATELLITE
# ...

# %%
#using parse() with parameters
products = excel_file.parse(sheet_name="Products", header=0, index_col="product_id")
products
# Out:
#                        price  merchant_id      brand  \
# product_id
# AVphzgbJLJeJML43fA0o  104.99         1001      Sanus
# AVpgMuGwLJeJML43KY_c   69.00         1002    Boytone
# AVpe9FXeLJeJML43zHrq   23.99         1001      DENAQ
# AVpfVJXu1cnluZ0-iwTT  290.99         1001  DreamWave
# AVphUeKeilAPnD_x3-Be  244.01         1004     Yamaha
# ...                      ...          ...        ...
# AVphFybdLJeJML43Wnza   64.95         1110        JBL
# AVpe_qIa1cnluZ0-bjrN  871.06         1002         HP
# AVphibxI1cnluZ0-DpxG   74.95         1238   Magellan
# AVpgrtW3ilAPnD_xv67M  294.35         1239   Pyle Pro
# AVpgibRDLJeJML43PTZX  129.99         1001       naxa
#
#                                                                    name
# product_id
# AVphzgbJLJeJML43fA0o  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# AVpgMuGwLJeJML43KY_c  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# AVpe9FXeLJeJML43zHrq           DENAQ - AC Adapter for TOSHIBA SATELLITE
# ...

# %%
products.dtypes # check the data types of each column in the DataFrame
# Out:
# price          float64
# merchant_id      int64
# brand           object
# name            object
# dtype: object

# %%
#now let's bring merchants sheet into a dataframe as well
merchants = excel_file.parse(sheet_name="Merchants", header=0, index_col="merchant_id")
merchants
# Out:
#                      merchant
# merchant_id
# 1001              Bestbuy.com
# 1002              Walmart.com
# 1003              Bestbuy.com
# 1004                 Growkart
# 1005         bhphotovideo.com
# ...                       ...
# 1236              PRIMESELLER
# 1237                  Spy Tec
# 1238              Action Gear
# 1239            Overstock.com
# 1240                  unknown
#
# [240 rows x 1 columns]

# %%
merchants.dtypes # check the data types of each column in the DataFrame
# Out:
# merchant    object
# dtype: object

# %%
# save excel file 
products.to_excel("exceloutput.xlsx") # this will create a new excel file with the dataframe's content

# %%
pd.read_excel("exceloutput.xlsx")
# Out:
#                 product_id   price  merchant_id      brand  \
# 0     AVphzgbJLJeJML43fA0o  104.99         1001      Sanus
# 1     AVpgMuGwLJeJML43KY_c   69.00         1002    Boytone
# 2     AVpe9FXeLJeJML43zHrq   23.99         1001      DENAQ
# 3     AVpfVJXu1cnluZ0-iwTT  290.99         1001  DreamWave
# 4     AVphUeKeilAPnD_x3-Be  244.01         1004     Yamaha
# ...                    ...     ...          ...        ...
# 1240  AVphFybdLJeJML43Wnza   64.95         1110        JBL
# 1241  AVpe_qIa1cnluZ0-bjrN  871.06         1002         HP
# 1242  AVphibxI1cnluZ0-DpxG   74.95         1238   Magellan
# 1243  AVpgrtW3ilAPnD_xv67M  294.35         1239   Pyle Pro
# 1244  AVpgibRDLJeJML43PTZX  129.99         1001       naxa
#
#                                                    name
# 0     Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# 1     Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 2              DENAQ - AC Adapter for TOSHIBA SATELLITE
# ...

# %%
# specify a sheet name when saving to avoid overwriting existing sheets
products.to_excel("exceloutput.xlsx", sheet_name="Products") # this will save the DataFrame into an existing excel file with "Products" as the sheet name, without deleting other sheets in that file

# %%
pd.read_excel("exceloutput.xlsx", sheet_name="Products")
# Out:
#                 product_id   price  merchant_id      brand  \
# 0     AVphzgbJLJeJML43fA0o  104.99         1001      Sanus
# 1     AVpgMuGwLJeJML43KY_c   69.00         1002    Boytone
# 2     AVpe9FXeLJeJML43zHrq   23.99         1001      DENAQ
# 3     AVpfVJXu1cnluZ0-iwTT  290.99         1001  DreamWave
# 4     AVphUeKeilAPnD_x3-Be  244.01         1004     Yamaha
# ...                    ...     ...          ...        ...
# 1240  AVphFybdLJeJML43Wnza   64.95         1110        JBL
# 1241  AVpe_qIa1cnluZ0-bjrN  871.06         1002         HP
# 1242  AVphibxI1cnluZ0-DpxG   74.95         1238   Magellan
# 1243  AVpgrtW3ilAPnD_xv67M  294.35         1239   Pyle Pro
# 1244  AVpgibRDLJeJML43PTZX  129.99         1001       naxa
#
#                                                    name
# 0     Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# 1     Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 2              DENAQ - AC Adapter for TOSHIBA SATELLITE
# ...

# %%
# position data with startrow and startcol parameters
products.to_excel("exceloutput2.xlsx", sheet_name="Products", startrow=10, startcol=2) # this will save the DataFrame into an existing excel file starting from row 10 and column 2 (C), without deleting other sheets in that file
# read back with pandas to check if it's correctly positioned   
pd.read_excel("exceloutput2.xlsx", sheet_name="Products", header=None, index_col=None) # this will read the DataFrame from row 10 and column 2 (C), without headers or an index column
# Out:
#        0   1                     2       3     4         5  \
# 0    NaN NaN                   NaN     NaN   NaN       NaN
# 1    NaN NaN                   NaN     NaN   NaN       NaN
# 2    NaN NaN                   NaN     NaN   NaN       NaN
# 3    NaN NaN                   NaN     NaN   NaN       NaN
# 4    NaN NaN                   NaN     NaN   NaN       NaN
# ...   ..  ..                   ...     ...   ...       ...
# 1251 NaN NaN  AVphFybdLJeJML43Wnza   64.95  1110       JBL
# 1252 NaN NaN  AVpe_qIa1cnluZ0-bjrN  871.06  1002        HP
# 1253 NaN NaN  AVphibxI1cnluZ0-DpxG   74.95  1238  Magellan
# 1254 NaN NaN  AVpgrtW3ilAPnD_xv67M  294.35  1239  Pyle Pro
# 1255 NaN NaN  AVpgibRDLJeJML43PTZX  129.99  1001      naxa
#
#                                                       6
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# ...

# %%
#saving multiple sheets to one excel file - ExcelWriter
writer = pd.ExcelWriter("exceloutput3.xlsx") # create a new Excel writer object with the name of the output file

# %%
with writer:
    products.to_excel(writer, sheet_name="Products", index=False) # save the DataFrame to "Products" sheet in the excel file
    merchants.to_excel(writer, sheet_name="Merchants", index=False) # save another DataFrame to "Merchants" sheet in the same excel file

# %%
pd.read_excel("exceloutput3.xlsx", sheet_name="Products") # read back with pandas to check if it's correctly positioned
# Out:
#        price  merchant_id      brand  \
# 0     104.99         1001      Sanus
# 1      69.00         1002    Boytone
# 2      23.99         1001      DENAQ
# 3     290.99         1001  DreamWave
# 4     244.01         1004     Yamaha
# ...      ...          ...        ...
# 1240   64.95         1110        JBL
# 1241  871.06         1002         HP
# 1242   74.95         1238   Magellan
# 1243  294.35         1239   Pyle Pro
# 1244  129.99         1001       naxa
#
#                                                    name
# 0     Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# 1     Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 2              DENAQ - AC Adapter for TOSHIBA SATELLITE
# 3     DreamWave - Tremor Portable Bluetooth Speaker ...
# 4     NS-SP1800BL 5.1-Channel Home Theater System (B...
# ...                                                 ...
# 1240  JBL - 6 x 9" 3-Way Car Speakers with Polypropy...
# 1241  HP - ProBook 14 Laptop - Intel Core i5 - 4GB M...
# ...

# %%
pd.read_excel("exceloutput3.xlsx", sheet_name="Merchants") # read back with pandas to check if it's correctly positioned
# Out:
#              merchant
# 0         Bestbuy.com
# 1         Walmart.com
# 2         Bestbuy.com
# 3            Growkart
# 4    bhphotovideo.com
# ..                ...
# 235       PRIMESELLER
# 236           Spy Tec
# 237       Action Gear
# 238     Overstock.com
# 239           unknown
#
# [240 rows x 1 columns]
